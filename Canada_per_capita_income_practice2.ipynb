# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('canada_per_capita_income.csv')

# %%
data
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
data.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
plt.scatter(data['year'], data['per capita income (US$)'], color='green')
plt.xlabel('Year')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
x = data.drop('per capita income (US$)', axis=1)
y = data['per capita income (US$)']

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([828.46507522])

# %%
model.intercept_
# Out:
# -1632210.7578554575

# %%
# y=mx+c
y=828.46507522*2016+-1632210.7578554575
y
# Out:
# 37974.833788062446

# %%
model.predict([[2016]])
# Out:
# C:\Users\conta\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37974.83379353])

# %%
pd.DataFrame({'True targets':y, 'Predicted targets':y_pred})
# Out:
#     True targets  Predicted targets
# 0    3399.299037        -134.559667
# 1    3768.297935         693.905409
# 2    4251.175484        1522.370484
# 3    4804.463248        2350.835559
# 4    5576.514583        3179.300634
# 5    5998.144346        4007.765709
# 6    7062.131392        4836.230785
# 7    7100.126170        5664.695860
# 8    7247.967035        6493.160935
# 9    7602.912681        7321.626010
# 10   8355.968120        8150.091086
# 11   9434.390652        8978.556161
# 12   9619.438377        9807.021236
# 13  10416.536590       10635.486311
# 14  10790.328720       11463.951386
# 15  11018.955850       12292.416462
# 16  11482.891530       13120.881537
# 17  12974.806620       13949.346612
# 18  15080.283450       14777.811687
# 19  16426.725480       15606.276763
# 20  16838.673200       16434.741838
# 21  17266.097690       17263.206913
# 22  16412.083090       18091.671988
# 23  15875.586730       18920.137063
# 24  15755.820270       19748.602139
# ...

# %%
plt.scatter(data['year'], data['per capita income (US$)'], color='green')
plt.xlabel('Year')
plt.ylabel('Income')
plt.plot(data['year'], y_pred, color='red')
